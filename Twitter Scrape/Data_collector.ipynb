# %% [markdown]
# # Import

# %%
import Exporter
import pymongo
import json
from pymongo import MongoClient
import regex as re
import pprint
import csv
import pandas as pd

# %% [markdown]
# ## Init server handler

# %%
#import configparser


PATH = './private_key.txt'

def get_setting(config_file):
    """ Read the config_file and construct an instance of TwitterAPI.
    Args:
      config_file ... A config file in ConfigParser format with Twitter credentials
    Returns:
      An instance of TwitterAPI.
    """
    ls_lines = list()
    dict_info = dict()
    pat = r"[\d|\w|\W]+\s="
    pat_content = r"'[\d|\w|\W]+'"
    with open(config_file,'r') as text_handler:
        ls_lines = text_handler.readlines()
        for line in ls_lines:
            dict_info[re.findall(pat,line)[0][:-2]] = re.findall(pat_content,line)[0][1:-1]
    return dict_info

dict_key =  get_setting(PATH)

MONGO_HOST_TW= "mongodb://{0}:{1}@ec2-52-87-161-70.compute-1.amazonaws.com/twitterdb".format(dict_key['mongo_db_user'],dict_key['mongo_db_password']) # assuming you have mongoDB installed locally
MONGO_HOST_Amazondb = "mongodb://{0}:{1}@ec2-52-87-161-70.compute-1.amazonaws.com/Amazondb".format(dict_key['mongo_db_user'],dict_key['mongo_db_password']) # assuming you have mongoDB installed locally

client_tw = MongoClient(MONGO_HOST_TW)
db_tw = client_tw.twitterdb
client_a = MongoClient(MONGO_HOST_Amazondb)
db_a = client_a.Amazondb

# %%
Exporter.main(['--querysearch', 'beautyblender', '--since', '2017-03-18','--until','2018-03-18', '--DB','--maxtweets','50'])
# Out:
# DB conecting....
# Searching...
#
# Upload End
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# ~\OneDrive\文件\CS 579\proj_git\Twitter Scrape\Exporter.py in main(argv)
#     118                 if hasattr(tweetCriteria,'DB'):
# --> 119                         got3.manager.TweetManager.getTweets(tweetCriteria, receiveBuffer_DB)
#     120                 else:
#
# ~\OneDrive\文件\CS 579\proj_git\Twitter Scrape\got3\manager\TweetManager.py in getTweets(tweetCriteria, receiveBuffer, bufferLength)
#      84                 if receiveBuffer and len(resultsAux) > 0:
# ---> 85                         receiveBuffer(resultsAux)
#      86                 else:
#
# ~\OneDrive\文件\CS 579\proj_git\Twitter Scrape\Exporter.py in receiveBuffer_DB(tweets)
#     100                         for t in tweets:
# --> 101                                 db.hello.insert_one(vars(t))
#     102                         print('More %d saved on file...\n' % len(tweets))
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     681                          bypass_doc_val=bypass_document_validation,
# --> 682                          session=session),
#     683             self.write_concern.acknowledged)
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     597                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 598                 bypass_doc_val, session)
#     599
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     577             result = self.__database.client._retryable_write(
# --> 578                 True, _insert_command, session)
#     579             _check_write_command_response(result)
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1097         """Internal retryable write helper."""
# -> 1098         with self._tmp_session(session) as s:
#    1099             return self._retry_with_session(retryable, func, s, None)
#
# C:\ProgramData\Anaconda3\envs\DL\lib\contextlib.py in __enter__(self)
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\mongo_client.py in _tmp_session(self, session, close)
#    1403
# -> 1404         s = self._ensure_session(session)
#    1405         if s and close:
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1390             # should always opt-in.
# -> 1391             return self.start_session(causal_consistency=False)
#    1392         except (ConfigurationError, InvalidOperation):
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\mongo_client.py in start_session(self, causal_consistency)
#    1368         # Raises ConfigurationError if sessions are not supported.
# -> 1369         server_session = self._get_server_session()
#    1370         opts = client_session.SessionOptions(
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1376         """Internal: start or resume a _ServerSession."""
# -> 1377         return self._topology.get_server_session()
#    1378
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     415                             self._settings.server_selection_timeout,
# --> 416                             None)
#     417                 elif not self._description.readable_servers:
#
# C:\ProgramData\Anaconda3\envs\DL\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     198                 raise ServerSelectionTimeoutError(
# --> 199                     self._error_message(selector))
#     200
#
# ServerSelectionTimeoutError: ec2-34-205-144-84.compute-1.amazonaws.com:27017: timed out
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5351359b4619> in <module>()
# ----> 1 Exporter.main(['--querysearch', 'beautyblender', '--since', '2017-12-12','--until','2018-02-16', '--DB','--maxtweets','50'])
#
# ~\OneDrive\文件\CS 579\proj_git\Twitter Scrape\Exporter.py in main(argv)
#     122
#     123
# --> 124         except arg:
#     125                 print('Arguments parser error, try -h' + arg)
#     126         finally:
#
# TypeError: catching classes that do not inherit from BaseException is not allowed

# %%
db_a.collection_names()
# Out:
# ['brand_remove_list', 'sephora_test', 'brand_list', 'sephora_check', 'sephora']

# %%
df = pd.DataFrame.from_records(db_a.sephora.find({"p_category":"Eyeshadow"}))

# %%
df
# Out:
#                          _id             brand_name p_category       p_id  \
# 0   5a94a621a785ab1ca40d4665     Yves Saint Laurent  Eyeshadow    P416321
# 1   5a94a641a785ab1ca40d466a     Yves Saint Laurent  Eyeshadow    P416420
# 2   5a94a8c9a785ab1ca40d46e2          Wander Beauty  Eyeshadow    P414282
# 3   5a94a92ca785ab1ca40d46f5          Wander Beauty  Eyeshadow    P407379
# 4   5a94adcca785ab1ca40d47d7            Urban Decay  Eyeshadow    P411033
# 5   5a94ae79a785ab1ca40d47fb            Urban Decay  Eyeshadow    P378821
# 6   5a94aed4a785ab1ca40d480c            Urban Decay  Eyeshadow    P309813
# 7   5a94af60a785ab1ca40d4829              trèStiQue  Eyeshadow    P416378
# 8   5a94b0b5a785ab1ca40d486d           Touch In Sol  Eyeshadow    P409990
# 9   5a94b167a785ab1ca40d4890              Too Faced  Eyeshadow    P427340
# 46  5a94ef8fa785ab1ca40d54d6       MAKE UP FOR EVER  Eyeshadow    P427647
# 47  5a94f289a785ab1ca40d5567          Laura Mercier  Eyeshadow    P222436
# 48  5a94f2d1a785ab1ca40d5574          Laura Mercier  Eyeshadow    P285103
# 49  5a94f40ba785ab1ca40d55b0          Laura Mercier  Eyeshadow    P293605
# 50  5a94fef2a785ab1ca40d563e                Lancôme  Eyeshadow    P423276
# 51  5a950800a785ab1ca40d5806           KEVYN AUCOIN  Eyeshadow    P413195
# 52  5a950b42a785ab1ca40d58ad              Kat Von D  Eyeshadow    P397923
# 53  5a958917a785ab1ca40d5be0               Givenchy  Eyeshadow    P385745
# 54  5a958ac5a785ab1ca40d5c35  Giorgio Armani Beauty  Eyeshadow    P393439
# 55  5a958be2a785ab1ca40d5c6e  Giorgio Armani Beauty  Eyeshadow    P393434
# 56  5a959ec0a785ab1ca40d6019                   Dior  Eyeshadow    P382450
# 57  5a95a3a0a785ab1ca40d610d               COVER FX  Eyeshadow    P428036
# 58  5a95a5b1a785ab1ca40d6171              ColourPop  Eyeshadow    P426702
# 59  5a95a84ca785ab1ca40d61f1               CLINIQUE  Eyeshadow    P381916
# 60  5a95a873a785ab1ca40d61f9               CLINIQUE  Eyeshadow    P404091
# 61  5a95a910a785ab1ca40d6219               CLINIQUE  Eyeshadow    P376470
# 62  5a95a9f1a785ab1ca40d6247               CLINIQUE  Eyeshadow    P381918
#
#     p_num_reviews p_price  p_star  \
# 0               7  $30.00  3.5714
# 1               9  $30.00  4.1111
# 2              16  $24.00  3.0625
# 3              37    None  4.6486
# 4             219  $22.00  3.6073
# 5             820  $21.00  4.5159
# 6            2280  $20.00  4.6917
# 7              13  $24.00  4.1538
# 8             269  $25.00  3.8848
# 9              16  $17.00  4.8125
# 10              7  $36.00  3.1429
# 11             32  $46.00  4.5938
# 12             33  $36.00  3.5152
# 13            115  $62.00  4.3652
# 14             70  $14.00  4.7429
# 15             90  $22.00  4.7333
# 16             35  $38.00  4.5429
# 17             20  $35.00    3.95
# 18             50  $20.00    3.74
# 19            562  $32.00  3.6566
# 20           1941  $18.00  4.5214
# 21             81  $24.00  4.5309
# 22           1185  $24.00   4.519
# 23             38  $14.00  4.1842
# 24            364  $25.00  4.0549
# 25             28  $28.00  3.4286
# 26             42  $35.00  4.0714
# 27             45  $24.00  3.4667
# 28            164  $24.00  4.2561
# 29             12  $36.00  4.6667
# ..            ...     ...     ...
# 33           1984  $26.00  4.3367
# 34           2279  $36.00  4.4783
# 35             29  $29.00  4.7241
# 36              6  $29.00  4.1667
# 37             73  $28.00  3.9315
# 38             17  $28.00  3.5294
# 39             92  $20.00  3.7283
# 40            158  $24.00  3.9114
# 41            291  $28.00  4.2234
# 42            761  $23.00  4.3627
# 43            357  $15.00  4.2577
# 44            276  $25.00  4.1667
# 45             99  $25.00  4.2323
# 46            462  $17.00  4.4654
# 47            750  $25.00    4.44
